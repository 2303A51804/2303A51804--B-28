# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51804/2303A51804--B-28/blob/main/PDS_ASS_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

customers = pd.DataFrame({
    'customer_id': [1, 2, 3, 4, 5],
    'name': ['Ravi', 'Sneha', 'Amit', 'Priya', 'John'],
    'city': ['Hyderabad', 'Delhi', 'Hyderabad', 'Bangalore', 'Delhi']
})

print("Customers Dataset:")
print(customers, "\n")

transactions = pd.DataFrame({
    'transaction_id': [101, 102, 103, 104, 105, 106, 107],
    'customer_id': [1, 2, 1, 3, 4, 2, 5],
    'amount': [250, 400, 300, 150, 500, 200, 350]
})

print("Transactions Dataset:")
print(transactions, "\n")


merged = pd.merge(transactions, customers, on='customer_id', how='inner')
print("Merged Dataset:")
print(merged, "\n")


customer_spend = merged.groupby(['customer_id', 'name'])['amount'].sum().reset_index()
customer_spend = customer_spend.rename(columns={'amount': 'total_spend'})
print("Total Spend Per Customer:")
print(customer_spend, "\n")


city_spend = merged.groupby('city')['amount'].sum().reset_index()
city_spend = city_spend.rename(columns={'amount': 'city_total_spend'})
print("City-wise Spending:")
print(city_spend, "\n")

top_spender = customer_spend.loc[customer_spend['total_spend'].idxmax()]
print("Top Spender:")
print(top_spender, "\n")


print("Insights:")
print(f"- The top spender is {top_spender['name']} with a spend of {top_spender['total_spend']}.")
print("- City with maximum spending:")
print(city_spend.loc[city_spend['city_total_spend'].idxmax()])
# Out:
# Customers Dataset:
#    customer_id   name       city
# 0            1   Ravi  Hyderabad
# 1            2  Sneha      Delhi
# 2            3   Amit  Hyderabad
# 3            4  Priya  Bangalore
# 4            5   John      Delhi
#
# Transactions Dataset:
#    transaction_id  customer_id  amount
# 0             101            1     250
# 1             102            2     400
# 2             103            1     300
# 3             104            3     150
# 4             105            4     500
# 5             106            2     200
# 6             107            5     350
#
# Merged Dataset:
#    transaction_id  customer_id  amount   name       city
# 0             101            1     250   Ravi  Hyderabad
# 1             102            2     400  Sneha      Delhi
# 2             103            1     300   Ravi  Hyderabad
# 3             104            3     150   Amit  Hyderabad
# 4             105            4     500  Priya  Bangalore
# 5             106            2     200  Sneha      Delhi
# 6             107            5     350   John      Delhi
#
# Total Spend Per Customer:
#    customer_id   name  total_spend
# 0            1   Ravi          550
# 1            2  Sneha          600
# 2            3   Amit          150
# 3            4  Priya          500
# 4            5   John          350
#
# City-wise Spending:
#         city  city_total_spend
# 0  Bangalore               500
# 1      Delhi               950
# 2  Hyderabad               700
#
# Top Spender:
# customer_id        2
# name           Sneha
# total_spend      600
# Name: 1, dtype: object
#
# Insights:
# - The top spender is Sneha with a spend of 600.
# - City with maximum spending:
# city                Delhi
# city_total_spend      950
# Name: 1, dtype: object

# %%
import pandas as pd


patients = pd.DataFrame({
    'patient_id': [1, 2, 3, 4, 5],
    'name': ['Ravi', 'Sneha', 'Amit', 'Priya', 'Kiran'],
    'age': [30, 45, 28, 35, 50],
    'gender': ['M', 'F', 'M', 'F', 'M']
})

print("Patients Dataset:")
print(patients, "\n")

appointments = pd.DataFrame({
    'appointment_id': [101, 102, 103, 104, 105, 106, 107],
    'patient_id': [1, 2, 1, 3, 4, 5, 2],
    'doctor': ['Dr. Sharma', 'Dr. Gupta', 'Dr. Sharma',
               'Dr. Gupta', 'Dr. Rao', 'Dr. Rao', 'Dr. Gupta'],
    'date': ['2025-09-01', '2025-09-01', '2025-09-05',
             '2025-09-06', '2025-09-07', '2025-09-08', '2025-09-09']
})

print("Appointments Dataset:")
print(appointments, "\n")

merged = pd.merge(appointments, patients, on='patient_id', how='inner')
print("Merged Dataset:")
print(merged, "\n")


patient_visits = merged.groupby(['patient_id', 'name'])['appointment_id'].count().reset_index()
patient_visits = patient_visits.rename(columns={'appointment_id': 'total_visits'})
print("Appointments per Patient:")
print(patient_visits, "\n")

doctor_workload = merged.groupby('doctor')['appointment_id'].count().reset_index()
doctor_workload = doctor_workload.rename(columns={'appointment_id': 'total_appointments'})
print("Doctor Workload:")
print(doctor_workload, "\n")

top_patient = patient_visits.loc[patient_visits['total_visits'].idxmax()]
print("Patient with Maximum Visits:")
print(top_patient, "\n")


print("🔹 Insights:")
print(f"- The patient with the most hospital visits is {top_patient['name']} ({top_patient['total_visits']} visits).")
print(f"- The busiest doctor is {doctor_workload.loc[doctor_workload['total_appointments'].idxmax(), 'doctor']} "
      f"with {doctor_workload['total_appointments']} appointments.")
# Out:
# Patients Dataset:
#    patient_id   name  age gender
# 0           1   Ravi   30      M
# 1           2  Sneha   45      F
# 2           3   Amit   28      M
# 3           4  Priya   35      F
# 4           5  Kiran   50      M
#
# Appointments Dataset:
#    appointment_id  patient_id      doctor        date
# 0             101           1  Dr. Sharma  2025-09-01
# 1             102           2   Dr. Gupta  2025-09-01
# 2             103           1  Dr. Sharma  2025-09-05
# 3             104           3   Dr. Gupta  2025-09-06
# 4             105           4     Dr. Rao  2025-09-07
# 5             106           5     Dr. Rao  2025-09-08
# 6             107           2   Dr. Gupta  2025-09-09
#
# Merged Dataset:
#    appointment_id  patient_id      doctor        date   name  age gender
# 0             101           1  Dr. Sharma  2025-09-01   Ravi   30      M
# 1             102           2   Dr. Gupta  2025-09-01  Sneha   45      F
# 2             103           1  Dr. Sharma  2025-09-05   Ravi   30      M
# 3             104           3   Dr. Gupta  2025-09-06   Amit   28      M
# 4             105           4     Dr. Rao  2025-09-07  Priya   35      F
# 5             106           5     Dr. Rao  2025-09-08  Kiran   50      M
# 6             107           2   Dr. Gupta  2025-09-09  Sneha   45      F
#
# Appointments per Patient:
#    patient_id   name  total_visits
# 0           1   Ravi             2
# 1           2  Sneha             2
# 2           3   Amit             1
# 3           4  Priya             1
# 4           5  Kiran             1
#
# Doctor Workload:
#        doctor  total_appointments
# 0   Dr. Gupta                   3
# 1     Dr. Rao                   2
# 2  Dr. Sharma                   2
#
# Patient with Maximum Visits:
# patient_id         1
# name            Ravi
# total_visits       2
# Name: 0, dtype: object
#
# 🔹 Insights:
# - The patient with the most hospital visits is Ravi (2 visits).
# - The busiest doctor is Dr. Gupta with 0    3
# 1    2
# 2    2
# Name: total_appointments, dtype: int64 appointments.
